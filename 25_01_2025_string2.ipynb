# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauri210524/python-string-practice-question/blob/main/25_01_2025_string2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#find palindron
a=input()
b=(a[::-1])
if a==b:
  print("palindrone")
else:
   print("not palindrone")
# Out:
# acca
# palindrone

# %%
# find anagram
a=input()
b=input()
print(sorted(a))
print(sorted(b))
if sorted(a)==sorted(b):
  print("anagram")
else:
  print("not anagram")
# Out:
# listen
# silent
# ['e', 'i', 'l', 'n', 's', 't']
# ['e', 'i', 'l', 'n', 's', 't']
# anagram

# %%
a=input()
b=input()
if a==b:
  print('equal')
else:
  print('not equal')
# Out:
# amit
# amit
# equal
