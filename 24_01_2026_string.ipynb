# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauri210524/python-string-practice-question/blob/main/24_01_2026_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
course='python'
print(course[-1])
# Out:
# n

# %%
course='python'
print(course[0:3])
# Out:
# pyt

# %%
course='python'
print(course[::-1])
# Out:
# nohtyp

# %%
name=input()
print(name[::-1])
# Out:
# gauri
# iruag

# %%
name='gauri'
print(name[0])
# Out:
# g

# %%
name='gauri'
print(name[-1])
# Out:
# i

# %%
name='gauri'
print(name[:3])
# Out:
# gau

# %%
name='gauri'
print(name.upper())
print(name.title())
print(name.lower())
# Out:
# GAURI
# Gauri
# gauri

# %%
name='    gauri '
print(name.strip())
# Out:
# gauri

# %%
# immp
city='new-york'
city.replace('-',' ')
# Out:
# 'new york'

# %%
email='abc@bmail.com'
print(email.find('@'))
print(email.count('a'))
# Out:
# 3
# 2

# %%
text='python'
print(text.isalpha())
print(text.isdigit())
print(text.isalnum())
print(text.startswith('A'))
print(text.endswith('.com'))
# Out:
# True
# False
# True
# False
# False

# %%
var='india'
#1=len(var)
for i in var:
 # print(i)
  print(i, end="")
# Out:
# india

# %%
from re import A
var='india'
VOWELS=['a','e','i','o','u','A','E','I','O','U']
count=0
for i in var:
  if i in VOWELS:
    count+=1
    print(count)
# Out:
# 1
# 2
# 3

# %%
var='india'
x=0
for i in var:
  if i==x:
    continue
  if var.count(i)>1:
    x=i
    print(i)
# Out:
# i

# %%
var=['akash','sharma']
' '.join(var)
# Out:
# 'akash sharma'
